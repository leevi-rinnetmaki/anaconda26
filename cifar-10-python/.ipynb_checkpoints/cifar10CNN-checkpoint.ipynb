# %% [markdown]
# # Cifar 10 luokitteluprojekti CNN

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import keras
from keras import layers
from keras.layers import Input, Dense, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import time
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Retrieving the data and prepairing it
# The targets are one-hot encoded into vectors as this will be later usefull with the softmax function. The features are normalized as without it, it wasn't able to learn anything.

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_test, x_val, y_test, y_val = train_test_split(
    x_test, y_test,
    test_size=0.5
)

y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)
y_val = keras.utils.to_categorical(y_val, 10)

mean = np.mean(x_train, axis=(0,1,2), keepdims=True)
std = np.std(x_train, axis=(0,1,2), keepdims=True)
x_train = (x_train-mean)/std
x_test = (x_test-mean)/std
x_val = (x_val-mean)/std

# %% [markdown]
# ## Adding layers and neurons.
# There are two convolutional blocks. Each block consists of a Conv2D layer with ReLU activation, BatchNormalization, and MaxPooling2D. The output is flattened, passed through a Dropout layer to prevent overfitting, and finally connected to a Dense layer with softmax activation to produce probabilitiess.

# %%
inputs = keras.Input(shape=(32,32,3))
x = keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
x = BatchNormalization()(x)
x = keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs, name="mnist_model")

# %% [markdown]
# ## Compiling and adding the appropriate callbacks
# The optimizer uses rmsprop to update weights and categorical crossentropy to determine the cost.
#
# The learning rate scheduler reduces the learning rate by 0.5, if the validation loss doesn't improve for 3 epochs, while making sure it never goes below 0.00005. This helps if the model learning is stuck.
#
# The early stop makes it so that if the model fails to improve for 8 epochs, it stops trying and returns to previous best parameters.

# %%
model.compile(
    optimizer="rmsprop",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=3,
    min_lr=1e-5
)

early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Fitting
# Fitting with 200 epochs and also measuring the time.

# %%
start = time.time()

history=model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=200,
    batch_size=32,
    callbacks=[lr_scheduler, early_stop]
)

end = time.time()
print(f"Training took {end - start:.2f} seconds")
# Out:
# Epoch 1/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 22ms/step - accuracy: 0.4424 - loss: 1.8016 - val_accuracy: 0.5848 - val_loss: 1.1992 - learning_rate: 0.0010
# Epoch 2/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.5812 - loss: 1.2191 - val_accuracy: 0.6314 - val_loss: 1.0475 - learning_rate: 0.0010
# Epoch 3/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.6287 - loss: 1.0695 - val_accuracy: 0.6624 - val_loss: 0.9712 - learning_rate: 0.0010
# Epoch 4/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.6554 - loss: 0.9978 - val_accuracy: 0.6942 - val_loss: 0.8921 - learning_rate: 0.0010
# Epoch 5/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.6710 - loss: 0.9502 - val_accuracy: 0.7070 - val_loss: 0.8647 - learning_rate: 0.0010
# Epoch 6/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.6833 - loss: 0.9116 - val_accuracy: 0.6930 - val_loss: 0.8853 - learning_rate: 0.0010
# Epoch 7/200
# ...

# %% [markdown]
# ## Visualizing the data

# %%
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["val_accuracy"], label="validation accuracy")
plt.title("Model learning and performance")
plt.xlabel('Epochs')
plt.ylabel('Learning')
plt.legend()
plt.grid()
plt.show()

class_names = [
    "airplane","automobile","bird","cat","deer",
    "dog","frog","horse","ship","truck"
]

y_test_labels = np.argmax(y_test, axis=1)
indices = [np.where(y_test_labels == i)[0][0] for i in range(10)]
predictions = model.predict(x_test[indices])

for i, idx in enumerate(indices):
    plt.figure(figsize=(10,3))
    true = y_test_labels[idx]
    plt.subplot(1,2,2)
    bars = plt.bar(class_names, predictions[i])
    bars[true].set_color("green")
    plt.xticks(rotation=45)
    plt.ylim(0, 1)
    plt.title(f"True class: {class_names[true]}") 
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
