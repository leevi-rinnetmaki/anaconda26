# %% [markdown]
# # Cifar 10 luokitteluprojekti FCN

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import keras
from keras import layers
from keras.layers import Input, Dense, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import time
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Retrieving the data and prepairing it
# The targets are one-hot encoded into vectors as this will be later usefull with the softmax function. The features are normalized as without it, it wasn't able to learn anything.

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_test, x_val, y_test, y_val = train_test_split(
    x_test, y_test,
    test_size=0.5
)

y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)
y_val = keras.utils.to_categorical(y_val, 10)

mean = np.mean(x_train, axis=(0,1,2), keepdims=True)
std = np.std(x_train, axis=(0,1,2), keepdims=True)
x_train = (x_train-mean)/std
x_test = (x_test-mean)/std
x_val = (x_val-mean)/std

# %% [markdown]
# ## Adding the layers and neurons
# Each hidden layer has 512 neurons and there are 3 hidden layers. There is also an aggressive amount of dropout added to help with overfitting. ReLU is used to add non-linearity.

# %%
model = keras.models.Sequential([
    Input(shape=(32,32,3)),
    Flatten(),
    
    Dense(512),
    BatchNormalization(),
    keras.layers.Activation("relu"),
    Dropout(0.5),
    
    Dense(512),
    BatchNormalization(),
    keras.layers.Activation("relu"),
    Dropout(0.5),
    
    Dense(512),
    BatchNormalization(),
    keras.layers.Activation("relu"),
    Dropout(0.5),
    
    Dense(10, activation="softmax")
])

# %% [markdown]
# ## Compiling and adding the appropriate callbacks
# The optimizer uses rmsprop to update weights and categorical crossentropy to determine the cost.
#
# The learning rate scheduler reduces the learning rate by 0.5, if the validation loss doesn't improve for 3 epochs, while making sure it never goes below 0.00005. This helps if the model learning is stuck.
#
# The early stop makes it so that if the model fails to improve for 8 epochs, it stops trying and returns to previous best parameters.

# %%
model.compile(
    optimizer="rmsprop",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=3,
    min_lr=1e-5
)

early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Fitting
# Fitting with 200 epochs and also measuring the time.

# %%
start = time.time()

history=model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=200,
    batch_size=64,
    callbacks=[lr_scheduler, early_stop]
)

end = time.time()
print(f"Training took {end - start:.2f} seconds")
# Out:
# Epoch 1/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - accuracy: 0.3106 - loss: 1.9951 - val_accuracy: 0.4202 - val_loss: 1.6154 - learning_rate: 0.0010
# Epoch 2/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.3954 - loss: 1.6900 - val_accuracy: 0.4670 - val_loss: 1.5143 - learning_rate: 0.0010
# Epoch 3/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.4298 - loss: 1.6024 - val_accuracy: 0.4720 - val_loss: 1.4822 - learning_rate: 0.0010
# Epoch 4/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.4472 - loss: 1.5601 - val_accuracy: 0.4956 - val_loss: 1.4117 - learning_rate: 0.0010
# Epoch 5/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.4596 - loss: 1.5252 - val_accuracy: 0.4978 - val_loss: 1.4018 - learning_rate: 0.0010
# Epoch 6/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.4749 - loss: 1.4945 - val_accuracy: 0.5128 - val_loss: 1.3700 - learning_rate: 0.0010
# Epoch 7/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.4824 - loss: 1.4682 - val_accuracy: 0.5234 - val_loss: 1.3568 - learning_rate: 0.0010
# Epoch 8/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.4869 - loss: 1.4528 - val_accuracy: 0.5206 - val_loss: 1.3621 - learning_rate: 0.0010
# Epoch 9/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.4981 - loss: 1.4329 - val_accuracy: 0.5240 - val_loss: 1.3409 - learning_rate: 0.0010
# Epoch 10/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5033 - loss: 1.4127 - val_accuracy: 0.5324 - val_loss: 1.3245 - learning_rate: 0.0010
# Epoch 11/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5078 - loss: 1.4004 - val_accuracy: 0.5322 - val_loss: 1.3124 - learning_rate: 0.0010
# Epoch 12/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5140 - loss: 1.3866 - val_accuracy: 0.5378 - val_loss: 1.2993 - learning_rate: 0.0010
# Epoch 13/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.5203 - loss: 1.3701 - val_accuracy: 0.5342 - val_loss: 1.3021 - learning_rate: 0.0010
# Epoch 14/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5241 - loss: 1.3642 - val_accuracy: 0.5336 - val_loss: 1.3011 - learning_rate: 0.0010
# Epoch 15/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5321 - loss: 1.3489 - val_accuracy: 0.5430 - val_loss: 1.2768 - learning_rate: 0.0010
# Epoch 16/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5313 - loss: 1.3369 - val_accuracy: 0.5490 - val_loss: 1.2837 - learning_rate: 0.0010
# Epoch 17/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5346 - loss: 1.3260 - val_accuracy: 0.5526 - val_loss: 1.2741 - learning_rate: 0.0010
# Epoch 18/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5407 - loss: 1.3149 - val_accuracy: 0.5420 - val_loss: 1.2731 - learning_rate: 0.0010
# Epoch 19/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5430 - loss: 1.3056 - val_accuracy: 0.5498 - val_loss: 1.2669 - learning_rate: 0.0010
# Epoch 20/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5452 - loss: 1.2953 - val_accuracy: 0.5574 - val_loss: 1.2629 - learning_rate: 0.0010
# Epoch 21/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5460 - loss: 1.2920 - val_accuracy: 0.5446 - val_loss: 1.2700 - learning_rate: 0.0010
# Epoch 22/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5509 - loss: 1.2797 - val_accuracy: 0.5490 - val_loss: 1.2528 - learning_rate: 0.0010
# Epoch 23/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5555 - loss: 1.2680 - val_accuracy: 0.5466 - val_loss: 1.2611 - learning_rate: 0.0010
# Epoch 24/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.5573 - loss: 1.2611 - val_accuracy: 0.5556 - val_loss: 1.2481 - learning_rate: 0.0010
# Epoch 25/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5631 - loss: 1.2563 - val_accuracy: 0.5628 - val_loss: 1.2458 - learning_rate: 0.0010
# Epoch 26/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5634 - loss: 1.2382 - val_accuracy: 0.5548 - val_loss: 1.2408 - learning_rate: 0.0010
# Epoch 27/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5657 - loss: 1.2332 - val_accuracy: 0.5576 - val_loss: 1.2492 - learning_rate: 0.0010
# Epoch 28/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5728 - loss: 1.2181 - val_accuracy: 0.5566 - val_loss: 1.2368 - learning_rate: 0.0010
# Epoch 29/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5730 - loss: 1.2221 - val_accuracy: 0.5598 - val_loss: 1.2320 - learning_rate: 0.0010
# Epoch 30/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5755 - loss: 1.2069 - val_accuracy: 0.5608 - val_loss: 1.2164 - learning_rate: 0.0010
# Epoch 31/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5744 - loss: 1.2047 - val_accuracy: 0.5598 - val_loss: 1.2335 - learning_rate: 0.0010
# Epoch 32/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5833 - loss: 1.1902 - val_accuracy: 0.5564 - val_loss: 1.2364 - learning_rate: 0.0010
# Epoch 33/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5842 - loss: 1.1862 - val_accuracy: 0.5620 - val_loss: 1.2199 - learning_rate: 0.0010
# Epoch 34/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5988 - loss: 1.1416 - val_accuracy: 0.5690 - val_loss: 1.1971 - learning_rate: 5.0000e-04
# Epoch 35/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6032 - loss: 1.1270 - val_accuracy: 0.5690 - val_loss: 1.2038 - learning_rate: 5.0000e-04
# Epoch 36/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6050 - loss: 1.1187 - val_accuracy: 0.5694 - val_loss: 1.2006 - learning_rate: 5.0000e-04
# Epoch 37/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6087 - loss: 1.1097 - val_accuracy: 0.5708 - val_loss: 1.1949 - learning_rate: 5.0000e-04
# Epoch 38/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6120 - loss: 1.1058 - val_accuracy: 0.5662 - val_loss: 1.1982 - learning_rate: 5.0000e-04
# Epoch 39/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6143 - loss: 1.0957 - val_accuracy: 0.5722 - val_loss: 1.1973 - learning_rate: 5.0000e-04
# Epoch 40/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6170 - loss: 1.0873 - val_accuracy: 0.5686 - val_loss: 1.2024 - learning_rate: 5.0000e-04
# Epoch 41/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6276 - loss: 1.0615 - val_accuracy: 0.5750 - val_loss: 1.1931 - learning_rate: 2.5000e-04
# Epoch 42/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6276 - loss: 1.0510 - val_accuracy: 0.5778 - val_loss: 1.1940 - learning_rate: 2.5000e-04
# Epoch 43/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6309 - loss: 1.0471 - val_accuracy: 0.5814 - val_loss: 1.1947 - learning_rate: 2.5000e-04
# Epoch 44/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6308 - loss: 1.0460 - val_accuracy: 0.5780 - val_loss: 1.1936 - learning_rate: 2.5000e-04
# Epoch 45/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6370 - loss: 1.0346 - val_accuracy: 0.5776 - val_loss: 1.1920 - learning_rate: 1.2500e-04
# Epoch 46/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6382 - loss: 1.0269 - val_accuracy: 0.5774 - val_loss: 1.1929 - learning_rate: 1.2500e-04
# Epoch 47/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6414 - loss: 1.0198 - val_accuracy: 0.5760 - val_loss: 1.1927 - learning_rate: 1.2500e-04
# Epoch 48/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6420 - loss: 1.0146 - val_accuracy: 0.5786 - val_loss: 1.1923 - learning_rate: 1.2500e-04
# Epoch 49/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6467 - loss: 1.0052 - val_accuracy: 0.5794 - val_loss: 1.1950 - learning_rate: 6.2500e-05
# Epoch 50/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6462 - loss: 1.0104 - val_accuracy: 0.5758 - val_loss: 1.1938 - learning_rate: 6.2500e-05
# Epoch 51/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6472 - loss: 1.0048 - val_accuracy: 0.5746 - val_loss: 1.1946 - learning_rate: 6.2500e-05
# Epoch 52/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6479 - loss: 1.0025 - val_accuracy: 0.5746 - val_loss: 1.1944 - learning_rate: 3.1250e-05
# Epoch 53/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6477 - loss: 1.0069 - val_accuracy: 0.5782 - val_loss: 1.1948 - learning_rate: 3.1250e-05
# Training took 875.62 seconds

# %% [markdown]
# Presenting the data visually

# %%
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["val_accuracy"], label="validation accuracy")
plt.title("Model learning and performance")
plt.xlabel('Epochs')
plt.ylabel('Learning')
plt.legend()
plt.grid()
plt.show()

class_names = [
    "airplane","automobile","bird","cat","deer",
    "dog","frog","horse","ship","truck"
]

y_test_labels = np.argmax(y_test, axis=1)
indices = [np.where(y_test_labels == i)[0][0] for i in range(10)]
predictions = model.predict(x_test[indices])

for i, idx in enumerate(indices):
    plt.figure(figsize=(10,3))
    true = y_test_labels[idx]
    plt.subplot(1,2,2)
    bars = plt.bar(class_names, predictions[i])
    bars[true].set_color("green")
    plt.xticks(rotation=45)
    plt.ylim(0, 1)
    plt.title(f"True class: {class_names[true]}") 
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
